# %% [markdown]
# [I got my dataset from a site that provides free data related to COVID 19.](https://apidocs.covidactnow.org/)

# %% [markdown]
# In this raw dataset, there is an overwhelming amount of detailed information regarding each state's current COVID situation. There are a few columns that relate to vaccine distribution, and those are the columns I plan to use. This dataset, however, is a bit outdated due to me downloading it last week, so I will have to download an updated version soon. I can use this to find out which states are doing the best at vaccine distribution and which states are doing much worse.

# %% [markdown]
# [Here is the dataset](https://drive.google.com/file/d/17FJk7gENW4wZSICk41Mvg9d18tiDg6b9/view?usp=sharing)

# %% [markdown]
# What I hope to get from this dataset is to be able to rank states based on how well their vaccine distribution is, and directly see how Ohio compares to the best state and to the worst state. I can use this data in interviews with state representatives so I will know exactly where Ohio falls on the list.

# %%
import pandas as pd

# %%
df = pd.read_csv('states.csv')

# %%
df.head(10)
# Out:
#    fips country state  county  level  lat          locationId  long  \
# 0     2     USA    AK     NaN  state  NaN  iso1:us#iso2:us-ak   NaN
# 1     1     USA    AL     NaN  state  NaN  iso1:us#iso2:us-al   NaN
# 2     5     USA    AR     NaN  state  NaN  iso1:us#iso2:us-ar   NaN
# 3     4     USA    AZ     NaN  state  NaN  iso1:us#iso2:us-az   NaN
# 4     6     USA    CA     NaN  state  NaN  iso1:us#iso2:us-ca   NaN
# 5     8     USA    CO     NaN  state  NaN  iso1:us#iso2:us-co   NaN
# 6     9     USA    CT     NaN  state  NaN  iso1:us#iso2:us-ct   NaN
# 7    11     USA    DC     NaN  state  NaN  iso1:us#iso2:us-dc   NaN
# 8    10     USA    DE     NaN  state  NaN  iso1:us#iso2:us-de   NaN
# 9    12     USA    FL     NaN  state  NaN  iso1:us#iso2:us-fl   NaN
#
#    population  metrics.testPositivityRatio  ...  \
# 0      731545                     0.021568  ...
# 1     4903185                     0.058056  ...
# 2     3017804                     0.026255  ...
# ...

# %%
df.tail(10)
# Out:
#     fips country state  county  level  lat          locationId  long  \
# 43    46     USA    SD     NaN  state  NaN  iso1:us#iso2:us-sd   NaN
# 44    47     USA    TN     NaN  state  NaN  iso1:us#iso2:us-tn   NaN
# 45    48     USA    TX     NaN  state  NaN  iso1:us#iso2:us-tx   NaN
# 46    49     USA    UT     NaN  state  NaN  iso1:us#iso2:us-ut   NaN
# 47    51     USA    VA     NaN  state  NaN  iso1:us#iso2:us-va   NaN
# 48    50     USA    VT     NaN  state  NaN  iso1:us#iso2:us-vt   NaN
# 49    53     USA    WA     NaN  state  NaN  iso1:us#iso2:us-wa   NaN
# 50    55     USA    WI     NaN  state  NaN  iso1:us#iso2:us-wi   NaN
# 51    54     USA    WV     NaN  state  NaN  iso1:us#iso2:us-wv   NaN
# 52    56     USA    WY     NaN  state  NaN  iso1:us#iso2:us-wy   NaN
#
#     population  metrics.testPositivityRatio  ...  \
# 43      884659                     0.076748  ...
# 44     6829174                     0.057269  ...
# 45    28995881                     0.071151  ...
# ...

# %%
df.shape
# Out:
# (53, 50)
